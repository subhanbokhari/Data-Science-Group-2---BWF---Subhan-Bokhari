# %% [markdown]
# # 🔴 Task 19 ->Statistical plotting with Seaborn (regression plots, distribution plots)

# %% [markdown]
# ## Sample Data Sets

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data1 = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 28],
    'Kids': [5, 2, 1],
    'City': ['New York', 'Chicago', 'Los Angeles']
}
df1 = pd.DataFrame(data1)

data2 = {
    'Product': ['Laptop', 'Smartphone', 'Tablet'],
    'Price': [999.2, 599.7, 399.8],
    'Quantity': [10, 20, 15]
}
df2 = pd.DataFrame(data2)

data3 = np.random.rand(10, 10)
df3 = pd.DataFrame(data3, columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'])

print("Dataframe 1:")
print(df1)
print("\nDataframe 2:")
print(df2)
print("\nDataframe 3:")
print(df3)
# Out:
# Dataframe 1:
#       Name  Age  Kids         City
# 0    Alice   25     5     New York
# 1      Bob   30     2      Chicago
# 2  Charlie   28     1  Los Angeles
#
# Dataframe 2:
#       Product  Price  Quantity
# 0      Laptop  999.2        10
# 1  Smartphone  599.7        20
# 2      Tablet  399.8        15
#
# Dataframe 3:
#           A         B         C         D         E         F         G  \
# 0  0.608671  0.298740  0.864851  0.930162  0.843171  0.711727  0.360055
# 1  0.696359  0.032738  0.365453  0.433434  0.547391  0.953859  0.125171
# 2  0.176349  0.801594  0.198903  0.282419  0.985480  0.154020  0.652330
# 3  0.487882  0.411655  0.343417  0.168074  0.451039  0.355036  0.374320
# 4  0.994336  0.801026  0.360971  0.462523  0.461649  0.738209  0.543939
# 5  0.538034  0.444564  0.252111  0.741354  0.334103  0.559072  0.430822
# 6  0.747738  0.631504  0.566489  0.057592  0.439418  0.272765  0.041692
# 7  0.437843  0.527548  0.255133  0.214560  0.970730  0.637994  0.910926
# ...

# %% [markdown]
# ## 1.Linear Regression Plot (sns.regplot)

# %%
sns.regplot(x='Age', y='Kids', data=df1)
plt.xlabel('Age')
plt.ylabel('Kids')
plt.show()

# %% [markdown]
# ## 2. Multiple Linear Regression Plot (sns.lmplot)

# %%
sns.lmplot(x='Price', y='Quantity', data=df2, hue='Product', height=6, aspect=1.5)
plt.xlabel('Price')
plt.ylabel('Quantity')
# Out:
# Text(38.33862654320988, 0.5, 'Quantity')

# %% [markdown]
# ## 3. Residual Plot (sns.residplot)

# %%
sns.residplot(x='Age', y='Age', data=df1)
plt.xlabel('Age')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# ## 4. Histogram (sns.histplot)

# %%
sns.histplot(data=df2, x='Price', hue='Product', multiple='stack', bins=10)
plt.xlabel('Price')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## 5. Kernel Density Estimate (KDE) Plot (sns.kdeplot)

# %%
sns.kdeplot(data=df1, x='Age', hue='City', fill=True, warn_singular=False)
plt.xlabel('Age')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# ## 6. Distribution Plot (sns.displot)

# %%
sns.displot(data=df2, x='Price', kde=True, bins=5, color='blue')
plt.xlabel('Price')
plt.ylabel('Density')
# Out:
# Text(9.444444444444445, 0.5, 'Density')

# %% [markdown]
# ## 7. Box Plot (sns.boxplot)

# %%
sns.boxplot(data=df1, x='Name', y='Kids', color='lightblue')
plt.xlabel('Name')
plt.ylabel('Kids')
# Out:
# Text(0, 0.5, 'Kids')

# %% [markdown]
# ## 8. Violin Plot (sns.violinplot)

# %%
sns.violinplot(data=df2, x='Product', y='Price', inner='quartile', hue='Product', legend=False)
plt.xlabel('Product')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## 9.Pair Plot (sns.pairplot)

# %%
sns.pairplot(data=df1, vars=['Age', 'Kids'])

# %% [markdown]
# ## 10. Heatmap (sns.heatmap)

# %%
sns.heatmap(df3.corr(), annot=True, cmap='YlOrRd')
plt.title('Heatmap of the Random DataFrame')
plt.show()

# %% [markdown]
# ## 11. Joint Plot (sns.jointplot)

# %%
sns.jointplot(x='A', y='B', data=df3, kind='scatter')

# %% [markdown]
# ## 13. Facet Grid (sns.FacetGrid)

# %%
data4 = {
    'Product': ['Product A', 'Product B', 'Product C', 'Product D', 'Product E'],
    'Sales': [100, 80, 120, 90, 110],
    'Profit': [20, 15, 25, 18, 22],
    'Inventory': [50, 40, 60, 45, 55],
    'Marketing_Spend': [10, 8, 12, 9, 11]
}

df4 = pd.DataFrame(data4)

g = sns.FacetGrid(df4, row='Inventory', col='Marketing_Spend', hue='Sales')
g.map(sns.scatterplot, 'Inventory', 'Profit')
g.add_legend()
